# %% [markdown]
# <a href="https://colab.research.google.com/github/janghanui/test/blob/main/Google_Drive_usage_sample.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 나의 Google Drive에 있는 File 을 Colab 에서 사용하는 방법
# 1. Colab 에서 Google Drive 를 Gdrive 로 Mount 한다. ( 여기서 "Gdrive" 은 원하는 어떤 이름도 가능함)

# %%
from google.colab import drive
drive.mount('Gdrive')
# Out:
# Mounted at Gdrive

# %% [markdown]
# 2. File 을 읽어본다 ( 읽기전 나의 Google Drive 해당 Folder 에 해당  File 이 있는지  Google Drive 에서 확인한다.)

# %%
import pandas as pd
df = pd.read_csv('Gdrive/My Drive/ds2021/housepricedata.csv')

# %% [markdown]
# 3. 읽은 File 내용을 출력한다.

# %%
df
# Out:
#       LotArea  OverallQual  ...  GarageArea  AboveMedianPrice
# 0        8450            7  ...         548                 1
# 1        9600            6  ...         460                 1
# 2       11250            7  ...         608                 1
# 3        9550            7  ...         642                 0
# 4       14260            8  ...         836                 1
# ...       ...          ...  ...         ...               ...
# 1455     7917            6  ...         460                 1
# 1456    13175            6  ...         500                 1
# 1457     9042            7  ...         252                 1
# 1458     9717            5  ...         240                 0
# 1459     9937            5  ...         276                 0
#
# [1460 rows x 11 columns]

# %%
1+1
# Out:
# 2

# %% [markdown]
# 테스트입니다
